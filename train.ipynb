# %%
from ultralytics import YOLO
import torch
import os

# %%
if 'CUDA_VISIBLE_DEVICES' in os.environ:
    del os.environ['CUDA_VISIBLE_DEVICES']

# 2. Check availability NOW
print(f"CUDA Available: {torch.cuda.is_available()}")
print(f"Device Count: {torch.cuda.device_count()}")
# Out:
# CUDA Available: True
# Device Count: 1

# %%
model = YOLO('yolov8s.pt')

data_config_path = 'dataset3/PartB/data.yaml'

results = model.train(data=data_config_path, epochs=100, imgsz=640, device=0, patience=50)

print("Training complete. Model saved in the 'runs/detect/' directory.")
# Out:
# New https://pypi.org/project/ultralytics/8.3.233 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.228  Python-3.12.6 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %%
model_path = 'models/head_detection_best.pt'
model = YOLO(model_path)

train_set = model.val(data="dataset3/PartB/data.yaml", split='train')
test_set =model.val(data="dataset3/PartB/data.yaml", split='test')
# Out:
# Ultralytics 8.3.228  Python-3.12.6 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 787.01187.9 MB/s, size: 155.5 KB)
# val: Scanning C:\Users\yarik\OneDrive\Desktop\Data Science\dataset3\PartB\train\labels... 1630 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1630/1630 435.4it/s 3.7s0.1s
# val: New cache created: C:\Users\yarik\OneDrive\Desktop\Data Science\dataset3\PartB\train\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 102/102 3.2it/s 31.5s0.3s
#                    all       1630      29284      0.932      0.915      0.965      0.596
# Speed: 1.1ms preprocess, 12.0ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to C:\Users\yarik\OneDrive\Desktop\Data Science\runs\detect\val3
# ...

# %%
print("Train Results")
print(f"mAP50-95 (Box): {train_set.box.map}")
print(f"mAP50 (Box): {train_set.box.map50}")
print(f"Precision (Box): {train_set.box.p[0]}") 
print(f"Recall (Box): {train_set.box.r[0]}")
# Out:
# Train Results
# mAP50-95 (Box): 0.5956083681923139
# mAP50 (Box): 0.9648077640808583
# Precision (Box): 0.9323079296076231
# Recall (Box): 0.9148340390657014

# %%
print("Test Results")
print(f"mAP50-95 (Box): {test_set.box.map}")
print(f"mAP50 (Box): {test_set.box.map50}")
print(f"Precision (Box): {test_set.box.p[0]}") 
print(f"Recall (Box): {test_set.box.r[0]}")
# Out:
# Test Results
# mAP50-95 (Box): 0.5606842299395302
# mAP50 (Box): 0.9542602816697466
# Precision (Box): 0.9125328092235351
# Recall (Box): 0.9068774142053332
